# %% [markdown]
# # Rock Paper Scissors
#
# Let's play the famous game against our computer.
#
# https://en.wikipedia.org/wiki/Rock%E2%80%93paper%E2%80%93scissors
#
# The use of functions is recommended
#
# ## Goals
# 1. Use of loop
# 2. Data capture by console
# 3. Use if-elif-else
# 4. Use of try-except
# 5. Definition of functions. Modular programming
# 6. Logical operators.
# 7. Print
# 8. Import modules

# %%
# Import the choice function of the random module
# https://stackoverflow.com/questions/306400/how-to-randomly-select-an-item-from-a-list
import random

# Assign to a list the 3 possible options: 'stone', 'paper' or 'scissors'.
OPTIONS = ["stone", "paper", "scissors"]

# Assign a variable to the maximum number of games: 1, 3, 5, etc ...
MAX_GAMES = 7

# Assign a variable to the number of games a player must win to win.
# Preferably the value will be based on the number of maximum games
WIN_GAMES = 4

# Define a function that randomly returns one of the 3 options.
# This will correspond to the play of the machine. Totally random.
def get_machine_choice(options):
    return random.choice(options)

# Define a function that asks your choice: 'stone', 'paper' or 'scissors'
# you should only allow one of the 3 options. This is defensive programming.
# If it is not stone, paper or scissors keep asking until it is.
def ask_player_choice(options):
    choice = ""
    while choice not in options:
        choice = input("Please enter your choice by typing exactly one of the following options: %s\n" % ", ".join(options)).lower()
        if choice not in options:
            print("Choice not found. Try again.")
    return choice

# Define a function that resolves a combat.
# Returns 0 if there is a tie, 1 if the machine wins, 2 if the human player wins
def get_result(machine_choice, player_choice):
    result = -1
    if player_choice == machine_choice:
        result = 0
    elif player_choice == "stone":
        if machine_choice == "scissors":
            result = 2
        else:
            result = 1
    elif player_choice == "paper":
        if machine_choice == "stone":
            result = 2
        else:
            result = 1
    elif player_choice == "scissors":
        if machine_choice == "paper":
            result = 2
        else:
            result = 1
    return result

# Define a function that shows the choice of each player and the state of the game
# This function should be used every time accumulated points are updated
def show_status(max_games, machine_choice, player_choice, machine_wins, player_wins):
    status = "\nLAST PLAY\n"
    status += "Machine's choice: %s.\n" % machine_choice
    status += "Player's choice: %s.\n" % player_choice
    result = get_result(machine_choice, player_choice)
    if result == 0:
        status += "Result: Tie.\n\n"
    elif result == 1:
        status += "Result: Machine wins.\n\n"
    elif result == 2:
        status += "Result: Player wins.\n\n"
    status += "GAME STATUS\n"
    status += "Round: %s/%s.\n" % (machine_wins + player_wins, max_games)
    status += "Machine's victories: %s.\n" % machine_wins
    status += "Player's victories: %s.\n\n" % player_wins
    return status

# Create two variables that accumulate the wins of each participant
MACHINE_WINS = 0
PLAYER_WINS = 0

# Create a loop that iterates while no player reaches the minimum of wins
# necessary to win. Inside the loop solves the play of the
# machine and ask the player's. Compare them and update the value of the variables
# that accumulate the wins of each participant.
try:
    while MACHINE_WINS < WIN_GAMES and PLAYER_WINS < WIN_GAMES:
        machine_choice = get_machine_choice(OPTIONS)
        player_choice = ask_player_choice(OPTIONS)
        result = get_result(machine_choice, player_choice)
        if result == 1:
            MACHINE_WINS += 1
        elif result == 2:
            PLAYER_WINS +=1
        print(show_status(MAX_GAMES, machine_choice, player_choice, MACHINE_WINS, PLAYER_WINS))
except:
    print("An error has occurred.")

# Print by console the winner of the game based on who has more accumulated wins
if PLAYER_WINS > MACHINE_WINS:
    print("Player wins the game.")
else:
    print("Machine wins the game.")
# Out:
# Please enter your choice by typing exactly one of the following options: stone, paper, scissors
# S
# Choice not found. Try again.
# Please enter your choice by typing exactly one of the following options: stone, paper, scissors
# Stone
#
# LAST PLAY
# Machine's choice: stone.
# Player's choice: stone.
# Result: Tie.
#
# GAME STATUS
# Round: 0/7.
# Machine's victories: 0.
# Player's victories: 0.
#
#
# Please enter your choice by typing exactly one of the following options: stone, paper, scissors
# STONE
#
# LAST PLAY
# Machine's choice: scissors.
# Player's choice: stone.
# Result: Player wins.
#
# GAME STATUS
# Round: 1/7.
# Machine's victories: 0.
# Player's victories: 1.
#
#
# Please enter your choice by typing exactly one of the following options: stone, paper, scissors
# stoNe
#
# LAST PLAY
# Machine's choice: stone.
# Player's choice: stone.
# Result: Tie.
#
# GAME STATUS
# Round: 1/7.
# Machine's victories: 0.
# Player's victories: 1.
#
#
# Please enter your choice by typing exactly one of the following options: stone, paper, scissors
# paper
#
# LAST PLAY
# Machine's choice: scissors.
# Player's choice: paper.
# Result: Machine wins.
#
# GAME STATUS
# Round: 2/7.
# Machine's victories: 1.
# Player's victories: 1.
#
#
# Please enter your choice by typing exactly one of the following options: stone, paper, scissors
# ors
# Choice not found. Try again.
# Please enter your choice by typing exactly one of the following options: stone, paper, scissors
# scissors
#
# LAST PLAY
# Machine's choice: scissors.
# Player's choice: scissors.
# Result: Tie.
#
# GAME STATUS
# Round: 2/7.
# Machine's victories: 1.
# Player's victories: 1.
#
#
# Please enter your choice by typing exactly one of the following options: stone, paper, scissors
# paper
#
# LAST PLAY
# Machine's choice: paper.
# Player's choice: paper.
# Result: Tie.
#
# GAME STATUS
# Round: 2/7.
# Machine's victories: 1.
# Player's victories: 1.
#
#
# Please enter your choice by typing exactly one of the following options: stone, paper, scissors
# paper
#
# LAST PLAY
# Machine's choice: stone.
# Player's choice: paper.
# Result: Player wins.
#
# GAME STATUS
# Round: 3/7.
# Machine's victories: 1.
# Player's victories: 2.
#
#
# Please enter your choice by typing exactly one of the following options: stone, paper, scissors
# paper
#
# LAST PLAY
# Machine's choice: stone.
# Player's choice: paper.
# Result: Player wins.
#
# GAME STATUS
# Round: 4/7.
# Machine's victories: 1.
# Player's victories: 3.
#
#
# Please enter your choice by typing exactly one of the following options: stone, paper, scissors
# stone
#
# LAST PLAY
# Machine's choice: paper.
# Player's choice: stone.
# Result: Machine wins.
#
# GAME STATUS
# Round: 5/7.
# Machine's victories: 2.
# Player's victories: 3.
#
#
# Please enter your choice by typing exactly one of the following options: stone, paper, scissors
# stone
#
# LAST PLAY
# Machine's choice: scissors.
# Player's choice: stone.
# Result: Player wins.
#
# GAME STATUS
# Round: 6/7.
# Machine's victories: 2.
# Player's victories: 4.
#
#
# Player wins the game.

# %% [markdown]
# ### **Expected output**: Depends on the inputs, you know how to play and what to expect.

# %% [markdown]
# # Bonus: Stone, paper, scissors, lizard, spock
#
# Now the improvement begins.
#
# ![](images/rpsls.jpg)
#
#
# http://www.samkass.com/theories/RPSSL.html
#
# You are asked to impliment some improvements with respect to the simple previous game. In addition, the number of games (which must be ODD) will be requested per console until a valid number is entered.
#
# Improvements:
# * 5 options: stone, paper, scissors, lizard, spock
# * The number of games is requested per console
# Tip: Reuse code that you already use. If you have programmed intelligently, the bonus are simple modifications to the original game.

# %%
# Import the choice function of the random module
import random

# Define a function that asks for an odd number on the keyboard, until it is not valid
# will keep asking
def ask_games_number():
    number = 0
    while number == 0 or (number % 2) == 0:
        data = input("Please enter an odd number that determines the maximum number of games\n:")
        if data.isdigit():
            if int(data) <= 0:
                print("Number must be greater than zero. Try again.")
            elif (int(data) % 2) == 0:
                print("Number must be odd. Try again.")
            else:
                number = int(data)
        else:
            print("Not a number. Try again.")
    return number

# Assign a list of 5 possible options.
OPTIONS = ["stone", "paper", "scissors", "lizard", "spock"]

# Assign a variable to the maximum number of games: 1, 3, 5, etc ...
# This time the previously defined function is used
MAX_GAMES = ask_games_number()

# Assign a variable to the number of games a player must win to win.
# Preferably the value will be based on the number of maximum games
WIN_GAMES = int(MAX_GAMES / 2) + 1

# Define a function that randomly returns one of the 5 options.
# This will correspond to the play of the machine. Totally random.
def get_machine_choice(options):
    return random.choice(options)

# Define a function that asks your choice between 5
# you should only allow one of the 5 options. This is defensive programming.
# If it is not valid, keep asking until it is valid.
def ask_player_choice(options):
    choice = ""
    while choice not in options:
        choice = input("Please enter your choice by typing exactly one of the following options: %s\n" % ", ".join(options)).lower()
        if choice not in options:
            print("Choice not found. Try again.")
    return choice

# Define a function that resolves a combat.
# Returns 0 if there is a tie, 1 if the machine wins, 2 if the human player wins
# Now there are more options
def get_result(machine_choice, player_choice):
    result = -1
    if player_choice == machine_choice:
        result = 0
    elif player_choice == "stone":
        if machine_choice in ["scissors", "lizard"]:
            result = 2
        else:
            result = 1
    elif player_choice == "paper":
        if machine_choice in ["stone", "spock"]:
            result = 2
        else:
            result = 1
    elif player_choice == "scissors":
        if machine_choice in ["paper", "lizard"]:
            result = 2
        else:
            result = 1
    elif player_choice == "lizard":
        if machine_choice in ["paper", "spock"]:
            result = 2
        else:
            result = 1
    elif player_choice == "spock":
        if machine_choice in ["stone", "scissors"]:
            result = 2
        else:
            result = 1
    return result

# Define a function that shows the choice of each player and the state of the game
# This function should be used every time accumulated points are updated
def show_status(max_games, machine_choice, player_choice, machine_wins, player_wins):
    status = "\nLAST PLAY\n"
    status += "Machine's choice: %s.\n" % machine_choice
    status += "Player's choice: %s.\n" % player_choice
    result = get_result(machine_choice, player_choice)
    if result == 0:
        status += "Result: Tie.\n\n"
    elif result == 1:
        status += "Result: Machine wins.\n\n"
    elif result == 2:
        status += "Result: Player wins.\n\n"
    status += "GAME STATUS\n"
    status += "Round: %s/%s.\n" % (machine_wins + player_wins, max_games)
    status += "Machine's victories: %s.\n" % machine_wins
    status += "Player's victories: %s.\n\n" % player_wins
    return status

# Create two variables that accumulate the wins of each participant
MACHINE_WINS = 0
PLAYER_WINS = 0

# Create a loop that iterates while no player reaches the minimum of wins
# necessary to win. Inside the loop solves the play of the
# machine and ask the player's. Compare them and update the value of the variables
# that accumulate the wins of each participant.
try:
    while MACHINE_WINS < WIN_GAMES and PLAYER_WINS < WIN_GAMES:
        machine_choice = get_machine_choice(OPTIONS)
        player_choice = ask_player_choice(OPTIONS)
        result = get_result(machine_choice, player_choice)
        if result == 1:
            MACHINE_WINS += 1
        elif result == 2:
            PLAYER_WINS +=1
        print(show_status(MAX_GAMES, machine_choice, player_choice, MACHINE_WINS, PLAYER_WINS))
except:
    print("An error has occurred.")

# Print by console the winner of the game based on who has more accumulated wins
if PLAYER_WINS > MACHINE_WINS:
    print("Player wins the game.")
else:
    print("Machine wins the game.")
# Out:
# Please enter an odd number that determines the maximum number of games
# :1oo
# Not a number. Try again.
# Please enter an odd number that determines the maximum number of games
# :0
# Number must be greater than zero. Try again.
# Please enter an odd number that determines the maximum number of games
# :-5
# Not a number. Try again.
# Please enter an odd number that determines the maximum number of games
# :2
# Number must be odd. Try again.
# Please enter an odd number that determines the maximum number of games
# :7
# Please enter your choice by typing exactly one of the following options: stone, paper, scissors, lizard, spock
# spok
# Choice not found. Try again.
# Please enter your choice by typing exactly one of the following options: stone, paper, scissors, lizard, spock
# SPOCK
#
# LAST PLAY
# Machine's choice: lizard.
# Player's choice: spock.
# Result: Machine wins.
#
# GAME STATUS
# Round: 1/7.
# Machine's victories: 1.
# Player's victories: 0.
#
#
# Please enter your choice by typing exactly one of the following options: stone, paper, scissors, lizard, spock
# SpoCK
#
# LAST PLAY
# Machine's choice: paper.
# Player's choice: spock.
# Result: Machine wins.
#
# GAME STATUS
# Round: 2/7.
# Machine's victories: 2.
# Player's victories: 0.
#
#
# Please enter your choice by typing exactly one of the following options: stone, paper, scissors, lizard, spock
# spock
#
# LAST PLAY
# Machine's choice: stone.
# Player's choice: spock.
# Result: Player wins.
#
# GAME STATUS
# Round: 3/7.
# Machine's victories: 2.
# Player's victories: 1.
#
#
# Please enter your choice by typing exactly one of the following options: stone, paper, scissors, lizard, spock
# lizard
#
# LAST PLAY
# Machine's choice: spock.
# Player's choice: lizard.
# Result: Player wins.
#
# GAME STATUS
# Round: 4/7.
# Machine's victories: 2.
# Player's victories: 2.
#
#
# Please enter your choice by typing exactly one of the following options: stone, paper, scissors, lizard, spock
# stone
#
# LAST PLAY
# Machine's choice: lizard.
# Player's choice: stone.
# Result: Player wins.
#
# GAME STATUS
# Round: 5/7.
# Machine's victories: 2.
# Player's victories: 3.
#
#
# Please enter your choice by typing exactly one of the following options: stone, paper, scissors, lizard, spock
# pàper
# Choice not found. Try again.
# Please enter your choice by typing exactly one of the following options: stone, paper, scissors, lizard, spock
# paper
#
# LAST PLAY
# Machine's choice: spock.
# Player's choice: paper.
# Result: Player wins.
#
# GAME STATUS
# Round: 6/7.
# Machine's victories: 2.
# Player's victories: 4.
#
#
# Player wins the game.

# %% [markdown]
# **Expected output**: Depends on the inputs, you know how to play and what to expect.
